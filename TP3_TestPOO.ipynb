# %%
from utilities import *
from TP3_3 import *

# %%
X_train, y_train, X_test, y_test = load_data()

# %%
print(X_train.shape)
print(y_train.shape)
print(np.unique(y_train, return_counts=True))
# Out:
# (1000, 64, 64)
# (1000, 1)
# (array([0., 1.]), array([500, 500]))

# %%
print(X_test.shape)
print(y_test.shape)
print(np.unique(y_test, return_counts=True))
# Out:
# (200, 64, 64)
# (200, 1)
# (array([0., 1.]), array([100, 100]))

# %%
X_train_reshape = X_train.reshape(X_train.shape[0], -1) / X_train.max()
X_train_reshape.shape
# Out:
# (1000, 4096)

# %%
X_test_reshape = X_test.reshape(X_test.shape[0], -1) / X_train.max()
X_test_reshape.shape
# Out:
# (200, 4096)

# %%
model = POO_model()

# %%
print(POO_model.__dict__)
# Out:
# {'__module__': 'TP3_3', '__init__': <function POO_model.__init__ at 0x000001A03C43FB00>, 'initialisation': <function POO_model.initialisation at 0x000001A0494D8400>, 'model': <function POO_model.model at 0x000001A0494D84A0>, 'log_loss': <function POO_model.log_loss at 0x000001A0494D8540>, 'gradients': <function POO_model.gradients at 0x000001A0494D85E0>, 'update': <function POO_model.update at 0x000001A0494D8680>, 'predict': <function POO_model.predict at 0x000001A0494D8720>, 'artificial_neuron': <function POO_model.artificial_neuron at 0x000001A0494D87C0>, '__dict__': <attribute '__dict__' of 'POO_model' objects>, '__weakref__': <attribute '__weakref__' of 'POO_model' objects>, '__doc__': None}

# %%
model.artificial_neuron(X_train_reshape, y_train, X_test_reshape, y_test, 0.01, 1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 106.18it/s]
